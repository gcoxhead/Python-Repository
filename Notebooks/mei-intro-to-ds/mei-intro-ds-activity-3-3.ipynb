# %% [markdown]
# # MEI Introduction to Data Science
#
# # Lesson 3 - Activity 3
#
# # Table of contents
# * [Introduction](#Introduction)
#  * [Problem](#Problem)
#  * [Importing the libraries and data](#Importing-the-libraries-and-data)
# * [Exploring the data](#Exploring-the-data)
#  * [Time series graphs](#Time-series-graphs)
#  * [Checkpoint 1](#Checkpoint-1)
#  * [Exploring a smaller subset of the data](#Exploring-a-smaller-subset-of-the-data)
# * [Communicating the result](#Communicating-the-result)
#  * [Checkpoint 2](#Checkpoint-2)
#
# # Introduction
#
# This activity uses the Seaborn library in Python to plot _time series_ so you can explore how measures change over time. More information about Seaborn can be seen at: https://seaborn.pydata.org/
#
# The activity uses the data from the MEI large data set (number 5) which has data about London boroughs and national regions between 2003 and 2019. For more information about the data see the short video at: https://mei.org.uk/introduction-to-data-science/large-data-sets/
#
# Note the data has been reformatted slightly compared to the published version, to put years into rows rather than columns.
#
# ## Problem
#
# ***How have income and house prices changed in different areas over time?***
#
# ## Importing the libraries and data
#
# > Run the code in the boxes below to import the `pandas` and `seaborn` libraries and create the `borough_data` data set.

# %%
import pandas as pd
import seaborn as sns

# %%
borough_data = pd.read_csv('../input/mei-large-data-set-5/MEI LDS 5 stacked years.csv')
# check the data
borough_data
# Out:
#       Area Code            Area    Region  Year  \
# 0     E09000001  City of London     Inner  2004
# 1     E09000001  City of London     Inner  2005
# 2     E09000001  City of London     Inner  2006
# 3     E09000001  City of London     Inner  2007
# 4     E09000001  City of London     Inner  2008
# ...         ...             ...       ...   ...
# 1741  W92000004           Wales  National  2013
# 1742  W92000004           Wales  National  2014
# 1743  W92000004           Wales  National  2015
# 1744  W92000004           Wales  National  2016
# 1745  W92000004           Wales  National  2017
#
#       ALL PUPILS AT END OF KS4 ACHIEVING 5+ A*-C INCLUDING ENGLISH AND MATHS  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1741                                                NaN
# 1742                                                NaN
# 1743                                                NaN
# 1744                                                NaN
# 1745                                                NaN
#
#       EMPLOYMENT RATE (AGED 16-64)  HOUSEHOLD WASTE RECYCLING RATE  \
# 0                              NaN                             NaN
# 1                             77.7                             NaN
# 2                             58.7                             NaN
# 3                             88.9                             NaN
# 4                             87.1                             NaN
# ...                            ...                             ...
# 1741                           NaN                             NaN
# 1742                           NaN                             NaN
# 1743                           NaN                             NaN
# 1744                           NaN                             NaN
# 1745                           NaN                             NaN
#
#       MEAN INCOME OF TAXPAYERS (£)  MEDIAN HOUSE PRICE (£)  \
# 0                              NaN                280000.0
# 1                              NaN                310000.0
# 2                              NaN                341000.0
# 3                              NaN                417500.0
# 4                              NaN                366250.0
# ...                            ...                     ...
# 1741                       25600.0                     NaN
# 1742                       26300.0                     NaN
# 1743                       27100.0                     NaN
# 1744                       27100.0                     NaN
# 1745                       28200.0                     NaN
#
#       MEDIAN INCOME OF TAXPAYERS (£)
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 1741                         20300.0
# 1742                         21000.0
# 1743                         21400.0
# 1744                         21700.0
# 1745                         22500.0
#
# [1746 rows x 10 columns]

# %% [markdown]
# # Exploring the data
#
# > Run the code below to check the data types.

# %%
borough_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746 entries, 0 to 1745
# Data columns (total 10 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Area Code                                                               1746 non-null   object
#  1   Area                                                                    1746 non-null   object
#  2   Region                                                                  1746 non-null   object
#  3   Year                                                                    1746 non-null   int64
#  4   ALL PUPILS AT END OF KS4 ACHIEVING 5+ A*-C INCLUDING ENGLISH AND MATHS  372 non-null    float64
#  5   EMPLOYMENT RATE (AGED 16-64)                                            641 non-null    float64
#  6   HOUSEHOLD WASTE RECYCLING RATE                                          672 non-null    float64
#  7   MEAN INCOME OF TAXPAYERS (£)                                            602 non-null    float64
#  8   MEDIAN HOUSE PRICE (£)                                                  645 non-null    float64
#  9   MEDIAN INCOME OF TAXPAYERS (£)                                          602 non-null    float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 136.5+ KB

# %% [markdown]
# You can make it easier to explore the data for the national regions by taking a copy of the data for which `Region` is equal to National.
#
# > Run the code below to create a new data set with just the national regions.

# %%
# create a slice of the data where Region = National
national_data = borough_data[borough_data['Region'] == 'National'].copy()
#check the data
national_data
# Out:
#       Area Code        Area    Region  Year  \
# 1347  E12000001  North East  National  2004
# 1348  E12000001  North East  National  2005
# 1349  E12000001  North East  National  2006
# 1350  E12000001  North East  National  2007
# 1351  E12000001  North East  National  2008
# ...         ...         ...       ...   ...
# 1741  W92000004       Wales  National  2013
# 1742  W92000004       Wales  National  2014
# 1743  W92000004       Wales  National  2015
# 1744  W92000004       Wales  National  2016
# 1745  W92000004       Wales  National  2017
#
#       ALL PUPILS AT END OF KS4 ACHIEVING 5+ A*-C INCLUDING ENGLISH AND MATHS  \
# 1347                                                NaN
# 1348                                                NaN
# 1349                                                NaN
# 1350                                                NaN
# 1351                                                NaN
# ...                                                 ...
# 1741                                                NaN
# 1742                                                NaN
# 1743                                                NaN
# 1744                                                NaN
# 1745                                                NaN
#
#       EMPLOYMENT RATE (AGED 16-64)  HOUSEHOLD WASTE RECYCLING RATE  \
# 1347                           NaN                             NaN
# 1348                          68.2                             NaN
# 1349                          69.2                             NaN
# 1350                          69.6                             NaN
# 1351                          68.3                             NaN
# ...                            ...                             ...
# 1741                           NaN                             NaN
# 1742                           NaN                             NaN
# 1743                           NaN                             NaN
# 1744                           NaN                             NaN
# 1745                           NaN                             NaN
#
#       MEAN INCOME OF TAXPAYERS (£)  MEDIAN HOUSE PRICE (£)  \
# 1347                           NaN                 96000.0
# 1348                           NaN                108950.0
# 1349                           NaN                119000.0
# 1350                           NaN                122500.0
# 1351                           NaN                120000.0
# ...                            ...                     ...
# 1741                       25600.0                     NaN
# 1742                       26300.0                     NaN
# 1743                       27100.0                     NaN
# 1744                       27100.0                     NaN
# 1745                       28200.0                     NaN
#
#       MEDIAN INCOME OF TAXPAYERS (£)
# 1347                             NaN
# 1348                             NaN
# 1349                             NaN
# 1350                             NaN
# 1351                             NaN
# ...                              ...
# 1741                         20300.0
# 1742                         21000.0
# 1743                         21400.0
# 1744                         21700.0
# 1745                         22500.0
#
# [399 rows x 10 columns]

# %% [markdown]
# ## Time-series graphs

# %% [markdown]
# You can see how median house prices have changed over time using a _time-series_ graph. In *Seaborn* a time series can be plotted using `relplot()` with `kind='line'`.
#
# > Run the code below to create a time-series of median house prices in the various national regions.

# %%
# time series of median house prices by national region
# lw=3 - thicker lines
sns.relplot(data=national_data, kind='line', x='Year', y='MEDIAN HOUSE PRICE (£)', hue='Area', lw=3, aspect=2);

# %% [markdown]
# > Add and run code below to create a time series of median income for the national regions.
# >
# > *Hint: You can copy the column name from the output of `info` above.*

# %%
# time series of median income by national region
sns.relplot(data=national_data, kind='line', x='Year', y='MEDIAN INCOME OF TAXPAYERS (£)', hue='Area', lw=3, aspect=2);

# %% [markdown]
# It is often preferable for the $y$-axis on a graph to start at zero, to avoid misleading the viewer by making small differences look bigger.
#
# > Run the code below to plot a graph where the *y*-axis starts at 0.

# %%
# define fig as a time series of median house prices with a y-axis that starts at zero
fig = sns.relplot(data=national_data, kind='line', x='Year', y='MEDIAN HOUSE PRICE (£)', hue='Area', lw=3, aspect=2);

# set the y-axis of fig to start at zero, and let seaborn decide the upper limit
fig.set(ylim=(0, None));

# %% [markdown]
# > Adapt the code for your time series for median income so that the $y$-axis starts at zero.

# %%
# time series of median income with a y-axis that starts at zero
fig = sns.relplot(data=national_data, kind='line', x='Year', y='MEDIAN INCOME OF TAXPAYERS (£)', hue='Area', lw=3, aspect=2);

# set the y-axis of fig to start at zero, and let seaborn decide the upper limit
fig.set(ylim=(0, None));

# %% [markdown]
# ## Checkpoint 1
#
# > * Describe how median house prices and median incomes have changed over time.
# > * How do the changes in London compare to the rest of the country?
# > * Look at the shape of the graph around 2008. What might explain this?

# %% [markdown]
# ## Exploring a smaller subset of the data
#
# There are too many boroughs for a time series for Inner London to be readable.
#
# > Run the code below to create a time series for median house prices in inner London boroughs.

# %%
# time series of median house prices for inner London boroughs
# lw=3 - thicker lines
sns.relplot(data=borough_data[borough_data['Region'] == 'Inner'], kind='line', x='Year', y='MEDIAN HOUSE PRICE (£)', hue='Area', lw=3, aspect=2);

# %% [markdown]
# Notice that:
# * the scale on the $y$-axis is now in millions (`1e6` is shorthand for the standard form notation $1×10^6$);
# * there are too many boroughs to distinguish the different colours.

# %% [markdown]
# > Run the code below to:
# > * create a subset of the data with just a few boroughs;
# > * plot a time series for this subset.

# %%
# filter the data to just Westminster, Newham and Hackney
selected_data = borough_data[(borough_data['Area'] == 'Westminster') 
                             | (borough_data['Area'] == 'Newham')
                             | (borough_data['Area'] == 'Hackney')].copy()

# check the data
selected_data
# Out:
#       Area Code         Area Region  Year  \
# 445   E09000012      Hackney  Inner  2004
# 446   E09000012      Hackney  Inner  2005
# 447   E09000012      Hackney  Inner  2006
# 448   E09000012      Hackney  Inner  2007
# 449   E09000012      Hackney  Inner  2008
# ...         ...          ...    ...   ...
# 1342  E09000033  Westminster  Inner  2014
# 1343  E09000033  Westminster  Inner  2015
# 1344  E09000033  Westminster  Inner  2016
# 1345  E09000033  Westminster  Inner  2017
# 1346  E09000033  Westminster  Inner  2018
#
#       ALL PUPILS AT END OF KS4 ACHIEVING 5+ A*-C INCLUDING ENGLISH AND MATHS  \
# 445                                                 NaN
# 446                                                 NaN
# 447                                                 NaN
# 448                                                 NaN
# 449                                                 NaN
# ...                                                 ...
# 1342                                                NaN
# 1343                                                NaN
# 1344                                                NaN
# 1345                                                NaN
# 1346                                                NaN
#
#       EMPLOYMENT RATE (AGED 16-64)  HOUSEHOLD WASTE RECYCLING RATE  \
# 445                            NaN                             NaN
# 446                           53.3                             NaN
# 447                           58.3                             NaN
# 448                           62.1                             NaN
# 449                           65.9                             NaN
# ...                            ...                             ...
# 1342                           NaN                       19.100000
# 1343                           NaN                       17.266120
# 1344                           NaN                       17.400000
# 1345                           NaN                       18.846207
# 1346                           NaN                       21.700000
#
#       MEAN INCOME OF TAXPAYERS (£)  MEDIAN HOUSE PRICE (£)  \
# 445                            NaN                216100.0
# 446                            NaN                220000.0
# 447                            NaN                245000.0
# 448                            NaN                264500.0
# 449                            NaN                265000.0
# ...                            ...                     ...
# 1342                      104000.0                     NaN
# 1343                      109000.0                     NaN
# 1344                      107000.0                     NaN
# 1345                      124000.0                     NaN
# 1346                           NaN                     NaN
#
#       MEDIAN INCOME OF TAXPAYERS (£)
# 445                              NaN
# 446                              NaN
# 447                              NaN
# 448                              NaN
# 449                              NaN
# ...                              ...
# 1342                         35100.0
# 1343                         37800.0
# 1344                         36100.0
# 1345                         39700.0
# 1346                             NaN
#
# [123 rows x 10 columns]

# %%
# time series of median house price for selected boroughs
sns.relplot(data=selected_data, kind='line', x='Year', y='MEDIAN HOUSE PRICE (£)', hue='Area', lw=3, aspect=2);

# %% [markdown]
# > Choose three more boroughs and add code below to:
# > * create a subset of the data for just those boroughs;
# > * plot a time series of median house prices for those boroughs;
# > * plot a time series of median income for those boroughs.

# %%
# filter the data to just three boroughs
# filter the data to just Westminster, Newham and Hackney
selected_data = borough_data[(borough_data['Area'] == 'Camden') 
                             | (borough_data['Area'] == 'Lewisham')
                             | (borough_data['Area'] == 'Kensington and Chelsea')].copy()

# check the data
selected_data
# Out:
#      Area Code      Area Region  Year  \
# 240  E09000007    Camden  Inner  2004
# 241  E09000007    Camden  Inner  2005
# 242  E09000007    Camden  Inner  2006
# 243  E09000007    Camden  Inner  2007
# 244  E09000007    Camden  Inner  2008
# ..         ...       ...    ...   ...
# 932  E09000023  Lewisham  Inner  2014
# 933  E09000023  Lewisham  Inner  2015
# 934  E09000023  Lewisham  Inner  2016
# 935  E09000023  Lewisham  Inner  2017
# 936  E09000023  Lewisham  Inner  2018
#
#      ALL PUPILS AT END OF KS4 ACHIEVING 5+ A*-C INCLUDING ENGLISH AND MATHS  \
# 240                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
# ..                                                 ...
# 932                                                NaN
# 933                                                NaN
# 934                                                NaN
# 935                                                NaN
# 936                                                NaN
#
#      EMPLOYMENT RATE (AGED 16-64)  HOUSEHOLD WASTE RECYCLING RATE  \
# 240                           NaN                             NaN
# 241                          64.4                             NaN
# 242                          66.0                             NaN
# 243                          67.1                             NaN
# 244                          67.7                             NaN
# ..                            ...                             ...
# 932                           NaN                       17.100000
# 933                           NaN                       17.999496
# 934                           NaN                       17.700000
# 935                           NaN                       21.823293
# 936                           NaN                       28.000000
#
#      MEAN INCOME OF TAXPAYERS (£)  MEDIAN HOUSE PRICE (£)  \
# 240                           NaN                308250.0
# 241                           NaN                325000.0
# 242                           NaN                358000.0
# 243                           NaN                410000.0
# 244                           NaN                439975.0
# ..                            ...                     ...
# 932                       32400.0                     NaN
# 933                       34500.0                     NaN
# 934                       35900.0                     NaN
# 935                       36800.0                     NaN
# 936                           NaN                     NaN
#
#      MEDIAN INCOME OF TAXPAYERS (£)
# 240                             NaN
# 241                             NaN
# 242                             NaN
# 243                             NaN
# 244                             NaN
# ..                              ...
# 932                         24900.0
# 933                         25800.0
# 934                         26700.0
# 935                         27300.0
# 936                             NaN
#
# [123 rows x 10 columns]

# %%
# time series of median house price for selected boroughs
sns.relplot(data=selected_data, kind='line', x='Year', y='MEDIAN HOUSE PRICE (£)', hue='Area', lw=3, aspect=2);

# %%
# time series of median income for selected boroughs
sns.relplot(data=selected_data, kind='line', x='Year', y='MEDIAN INCOME OF TAXPAYERS (£)', hue='Area', lw=3, aspect=2);

# %% [markdown]
# # Communicating the result
# ## Checkpoint 2
#
# > Use your analysis to answer the original problem:
# > ***How have income and house prices changed in different areas over time?***
