# %% [markdown]
# # MEI Introduction to Data Science
#
# # Activity 4a: Exploring car data
#
# # Table of contents
# * [Introduction](#Introduction)
#  - [Problem](#Problem)
#  - [Importing libraries and data](#Importing-libraries-and-data)
# * [Pre-processing the data](#Pre-processing-the-data)
# * [Exploring the data](#Exploring-the-data)
# * [Communicating the results](#Communicating-the-results)
#  - [Checkpoint](#Checkpoint)
#
#
# # Introduction
#
# In Lesson 4 you explored associations between engine size, mass and emissions for different types of car. In this activity you will investigate the differences between cars made in 2002 and those made in 2016.
#
# The activity uses the data from the AQA large data set which gives information about cars. For more information about the data see the short video at: https://mei.org.uk/introduction-to-data-science/large-data-sets/
#
# ## Problem
#
# ***How do emissions of cars made in 2016 compare to those made in 2002?***
#
# ## Importing libraries and data
#
# > Run the code below to import the libraries and the data.

# %%
import pandas as pd
import seaborn as sns

# %%
cars_data = pd.read_csv('../input/aqalds/AQA-large-data-set.csv')

# check the data
cars_data
# Out:
#       ReferenceNumber        Make  PropulsionTypeId  BodyTypeId   GovRegion  \
# 0                 440    VAUXHALL                 1          96      London
# 1                1465    VAUXHALL                 1          14  South West
# 2                3434  VOLKSWAGEN                 1          14  South West
# 3                1801    VAUXHALL                 1          14  South West
# 4                2330         BMW                 2          13  South West
# ...               ...         ...               ...         ...         ...
# 3822             2920        FORD                 2          14  North West
# 3823             1800        FORD                 2          96      London
# 3824             3498        FORD                 1          14  South West
# 3825             2802    VAUXHALL                 1          14  North West
# 3826             2073  VOLKSWAGEN                 2           6  South West
#
#       KeeperTitleId  EngineSize  YearRegistered  Mass  CO2     CO    NOX  \
# 0                 1        1598            2002  1970  190  0.219  0.026
# 1                 5        1398            2016  1163  118  0.463  0.010
# 2                 2        1395            2016  1316  113  0.242  0.033
# 3                 4        1598            2016  1355  159  0.809  0.012
# 4                 5        1995            2016  1445  114  0.180  0.023
# ...             ...         ...             ...   ...  ...    ...    ...
# 3822              5        1997            2016  1681  122  0.145  0.059
# 3823              2        1997            2016  1833  134  0.305  0.054
# 3824              1         999            2016  1333  108  0.447  0.030
# 3825              5        1364            2016  1409  149  0.699  0.008
# 3826              5        1598            2016  1485  107  0.243  0.039
#
#        part     hc  Random number
# 0       NaN  0.037       0.430217
# 1       NaN  0.031       0.797111
# 2       NaN  0.048       0.348442
# 3       NaN  0.051       0.968447
# 4       NaN    NaN       0.178227
# ...     ...    ...            ...
# 3822  0.001    NaN       0.946550
# 3823    NaN    NaN       0.538774
# 3824  0.002  0.076       0.736612
# 3825    NaN  0.044       0.748846
# 3826    NaN    NaN       0.427559
#
# [3827 rows x 15 columns]

# %% [markdown]
# # Pre-processing the data
#
# Some of the data cleaning and preparation will be familiar from previous lessons.
#
# > Run the code below to:
# > * remove rows with erroneous data;
# > * create a categorical feature for propulsion type.

# %%
# Keeping only the rows where EngineSize is greater than zero, Mass is greater than zero and CO2 is greater than zero
cleaned_cars_data = cars_data[(cars_data['EngineSize'] > 0) 
                            & (cars_data['Mass'] > 0)
                            & (cars_data['CO2'] > 0)].copy()

# create a PropulsionType feature based on the values of the PropulsionTypeID feature
cleaned_cars_data['PropulsionType'] = cars_data['PropulsionTypeId'].replace({1: 'Petrol',
                                                                             2: 'Diesel',
                                                                             3: 'Electric', 
                                                                             7: 'Gas/Petrol', 
                                                                             8: 'Electric/Petrol'})
# check the data
cleaned_cars_data
# Out:
#       ReferenceNumber        Make  PropulsionTypeId  BodyTypeId   GovRegion  \
# 0                 440    VAUXHALL                 1          96      London
# 1                1465    VAUXHALL                 1          14  South West
# 2                3434  VOLKSWAGEN                 1          14  South West
# 3                1801    VAUXHALL                 1          14  South West
# 4                2330         BMW                 2          13  South West
# ...               ...         ...               ...         ...         ...
# 3822             2920        FORD                 2          14  North West
# 3823             1800        FORD                 2          96      London
# 3824             3498        FORD                 1          14  South West
# 3825             2802    VAUXHALL                 1          14  North West
# 3826             2073  VOLKSWAGEN                 2           6  South West
#
#       KeeperTitleId  EngineSize  YearRegistered  Mass  CO2     CO    NOX  \
# 0                 1        1598            2002  1970  190  0.219  0.026
# 1                 5        1398            2016  1163  118  0.463  0.010
# 2                 2        1395            2016  1316  113  0.242  0.033
# 3                 4        1598            2016  1355  159  0.809  0.012
# 4                 5        1995            2016  1445  114  0.180  0.023
# ...             ...         ...             ...   ...  ...    ...    ...
# 3822              5        1997            2016  1681  122  0.145  0.059
# 3823              2        1997            2016  1833  134  0.305  0.054
# 3824              1         999            2016  1333  108  0.447  0.030
# 3825              5        1364            2016  1409  149  0.699  0.008
# 3826              5        1598            2016  1485  107  0.243  0.039
#
#        part     hc  Random number PropulsionType
# 0       NaN  0.037       0.430217         Petrol
# 1       NaN  0.031       0.797111         Petrol
# 2       NaN  0.048       0.348442         Petrol
# 3       NaN  0.051       0.968447         Petrol
# 4       NaN    NaN       0.178227         Diesel
# ...     ...    ...            ...            ...
# 3822  0.001    NaN       0.946550         Diesel
# 3823    NaN    NaN       0.538774         Diesel
# 3824  0.002  0.076       0.736612         Petrol
# 3825    NaN  0.044       0.748846         Petrol
# 3826    NaN    NaN       0.427559         Diesel
#
# [3733 rows x 16 columns]

# %% [markdown]
# The `YearRegistered` feature is a number, but in this activity you'll use it as a _category_. The following code converts the `YearRegistered` column to text so that *Seaborn* and *Pandas* intepret it as a category.
#
# > Run the code below to change the data type of `YearRegistered` to `category`.

# %%
# convert YearRegistered to text
cleaned_cars_data['YearRegistered'] = cleaned_cars_data['YearRegistered'].astype('category')

# show the data types
cleaned_cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3733 entries, 0 to 3826
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ReferenceNumber   3733 non-null   int64
#  1   Make              3733 non-null   object
#  2   PropulsionTypeId  3733 non-null   int64
#  3   BodyTypeId        3733 non-null   int64
#  4   GovRegion         3733 non-null   object
#  5   KeeperTitleId     3733 non-null   int64
#  6   EngineSize        3733 non-null   int64
#  7   YearRegistered    3733 non-null   category
#  8   Mass              3733 non-null   int64
#  9   CO2               3733 non-null   int64
#  10  CO                3730 non-null   float64
#  11  NOX               3731 non-null   float64
#  12  part              713 non-null    float64
#  13  hc                2390 non-null   float64
#  14  Random number     3733 non-null   float64
#  15  PropulsionType    3733 non-null   object
# dtypes: category(1), float64(5), int64(7), object(3)
# memory usage: 470.4+ KB

# %% [markdown]
# # Exploring the data
#
# To answer the problem you may wish to
#
# * Compare the statistics for different features for 2002 cars and 2016 cars: e.g. use `groupby('YearRegistered)` and `describe` $CO_2$ emissions.
# * Compare charts for different features for 2002 cars and 2016 cars: e.g. use `catplot` to create a box plot of emissions grouped by year.
# * Compare the scatter plots based on two features to identify any associations: e.g. use `relplot` to create a scatter plot of emissions against mass, with the colour determined by year
# * Take slices of the data: e.g. petrol cars, and see what the differences are for this type of car.

# %%
# start your analysis here

# Compare statistics of features for 2002 and 2016 cars
cleaned_cars_data.groupby('YearRegistered').describe()
# Out:
#                ReferenceNumber                                            \
#                          count         mean         std     min      25%
# YearRegistered
# 2002                    1206.0   643.311774  380.983491     1.0   317.25
# 2016                    2527.0  2562.633162  730.168852  1299.0  1930.50
#
#                                         PropulsionTypeId            ...  \
#                    50%      75%     max            count      mean  ...
# YearRegistered                                                      ...
# 2002             636.0   980.75  2408.0           1206.0  1.228027  ...
# 2016            2563.0  3194.50  3827.0           2527.0  1.760586  ...
#
#                    hc        Random number                                \
#                   75%    max         count      mean       std       min
# YearRegistered
# 2002            0.100  0.169        1206.0  0.515453  0.295630  0.004651
# 2016            0.051  0.076        2527.0  0.492594  0.288101  0.001541
#
#
#                      25%       50%       75%       max
# YearRegistered
# 2002            0.258146  0.537834  0.784822  0.999368
# 2016            0.245277  0.487913  0.740654  0.999888
#
# [2 rows x 96 columns]

# %%
#Compare charts for different features for 2002 cars and 2016 cars: e.g. use catplot to create a box plot 
#of emissions grouped by year.

# create box plots of Co2, grouped by year registered
sns.catplot(data=cleaned_cars_data, kind='box', x='CO2', y='YearRegistered', aspect=2);

# %%
#Compare the scatter plots based on two features to identify any associations: 
# e.g. use relplot to create a scatter plot of emissions against mass, with the colour determined by year
sns.relplot(data=cleaned_cars_data, x='CO2', y='Mass', aspect=2, hue='YearRegistered');

# %%
#Count the number of different propulsion types
sns.countplot(data = cleaned_cars_data, x= 'PropulsionType' )
# Out:
# <AxesSubplot:xlabel='PropulsionType', ylabel='count'>

# %%
#Take slices of the data: e.g. petrol cars, and see what the differences are for this type of car.

#Create a slice with only petrol cars

#GOT TO THIS POINT - CONTINUE HERE

sns.relplot(data=cleaned_cars_data, x='CO2', y='YearRegistered',aspect=2, hue='PropulsionType');

# %%
sns.stripplot(data=cleaned_cars_data, x='CO2', y='YearRegistered', hue='PropulsionType');

# %%
#Slice columns to leave only years registered and propulsion type feature categories
cleaned_cars_data_2 = cleaned_cars_data.reindex(columns = ['YearRegistered', 'PropulsionType', 'CO2'])

cleaned_cars_data_2.head()
# Out:
#   YearRegistered PropulsionType  CO2
# 0           2002         Petrol  190
# 1           2016         Petrol  118
# 2           2016         Petrol  113
# 3           2016         Petrol  159
# 4           2016         Diesel  114

# %%
cleaned_cars_data_2.describe()
# Out:
#                CO2
# count  3733.000000
# mean    136.872489
# std      36.005557
# min      13.000000
# 25%     114.000000
# 50%     128.000000
# 75%     158.000000
# max     356.000000

# %%
sns.catplot(data=cleaned_cars_data_2, x="YearRegistered", y="CO2", jitter = False, hue = 'PropulsionType')

# %%
#Create a violin plot
sns.catplot( data=cleaned_cars_data_2, x="CO2", y="YearRegistered", hue="PropulsionType", aspect =2, kind="violin",)

# %%
# Out:
# False

# %% [markdown]
# # Communicating the results
# ## Checkpoint
# > Use your analysis to answer the question: ***How do emissions of cars made in 2016 compare to those made in 2002?***
