# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
avocado_info = pd.read_csv("/kaggle/input/avocado-info-csv/avocado_info.csv")

# %%
avocado_info.head()
# Out:
#    Growth Duration  Fertilizer
# 0               98        True
# 1              108       False
# 2              129       False
# 3              116       False
# 4              111       False

# %%
fertilized = avocado_info.loc[avocado_info["Fertilizer"] == True, "Growth Duration"]

not_fertilized = avocado_info.loc[avocado_info["Fertilizer"] == False, "Growth Duration"]

# %%
np.random.choice(fertilized, size = len(fertilized))
# Out:
# array([101,  71,  97, 105, 119, 124, 143,  91, 117, 122,  98, 115, 120,
#         94, 104,  93, 111, 144, 142,  88, 115, 112, 146, 121, 136,  78,
#        146, 102, 104,  96, 103, 113, 129, 114, 108, 110,  84, 105, 103,
#         82, 115,  72,  82, 115,  98, 115, 104,  91, 130, 101, 117, 102,
#        110, 121, 154, 136, 127,  94, 117, 138,  65, 117, 122, 108, 132,
#        103, 110, 130, 106,  87, 114, 115, 144,  86, 123, 131, 127, 148,
#        130, 135, 146, 115,  92, 133, 116, 123, 141, 106, 122, 117, 146,
#        103, 101, 119, 105, 125, 127, 132, 105, 128, 122, 130, 115, 119,
#        131, 100,  72,  92, 141, 124, 113, 106,  95,  84, 117, 161,  86,
#        128, 124, 125, 150, 125, 103, 122,  95, 156,  98, 113, 123, 117,
#        101, 152, 130, 109, 119, 109, 132, 100,  98, 132, 105, 155, 115,
#        120, 123, 163, 108, 105,  99, 131, 107, 118, 123,  97, 145, 119,
#        116, 123, 163, 113, 100,  87, 144, 125,  77, 109,  87, 123, 117,
#        104, 118, 123, 116,  96, 131, 100,  93, 119,  94, 131, 109, 101,
#        105, 137, 113, 100, 133, 101, 115, 150, 119, 115, 126,  84, 117,
#        116, 113, 126, 144, 145, 135, 104,  96, 142, 104, 136, 107, 111,
#        140, 133, 107, 117,  72, 130, 122, 121, 121, 121,  87, 103, 132,
#        106, 125, 123, 116, 144, 131, 109, 153, 144, 123, 143, 108, 119,
#        144,  88, 123, 123, 106, 130, 102, 118, 114, 133, 123, 103, 148,
#        138, 143, 116, 125,  99, 135, 113, 119, 101,  91, 129, 123,  98,
#         96, 125, 114, 100, 125, 100,  88,  78, 128,  88,  98,  88, 120,
#        102, 155,  98,  98, 124, 131, 102, 127,  78, 105, 122,  71, 100,
#         99, 108, 146,  97, 117, 117, 130, 123, 123, 153, 119, 103, 127,
#        111, 115,  83, 108, 103, 144, 115,  87, 128,  95,  98, 119, 141,
#        121, 108, 120, 120, 129,  92, 115, 117, 124, 109, 161,  98, 128,
#        161, 115, 130, 143, 132, 103, 122, 140,  95, 116, 126, 111, 132,
#        101,  97, 123, 115, 102, 145, 139, 104,  82, 115, 108, 117, 127,
#         99, 154, 131,  99,  88, 106, 103, 114, 115, 117, 104, 145, 122,
#        120,  88,  86, 145, 108,  92, 127,  72, 115, 102, 110, 113, 113,
#        126, 129, 140,  96, 107, 140, 123, 117,  85,  88, 113,  94, 130,
#        122, 122,  68, 127, 144, 146, 133, 102, 131, 122, 124, 125, 107,
#        129,  95, 102, 130, 114, 123, 117, 108, 117, 137,  95, 104, 120,
#         75, 131, 104, 114, 119, 104, 106, 108, 100,  97,  97,  91, 104,
#        100, 104, 113, 119,  99, 100, 130, 127, 142, 125, 143, 133, 146,
#        115, 115, 104,  97, 129, 143, 134,  85,  72, 109, 129, 142, 101,
#        144, 125, 109, 112])

# %%
np.random.choice(not_fertilized, size = len(fertilized))
# Out:
# array([104, 126, 123,  65, 129, 138,  91, 114, 128, 127, 114, 114, 122,
#        174, 131, 113, 123, 137, 117, 121,  91, 144, 139, 125, 139,  85,
#        133, 137, 103, 120, 121, 104, 125, 119, 119, 131, 111, 119, 133,
#        119, 134, 136, 127, 112, 105, 134, 119, 133,  85, 120, 120, 125,
#        154, 100, 160, 116, 150, 140, 147, 120, 120, 115, 114, 126, 123,
#        138, 130, 117, 117, 130, 124, 141, 123, 120, 126, 119, 108, 113,
#        130, 137, 115, 138, 105, 146, 126, 111, 114, 151, 128, 129, 125,
#        100, 113, 136, 144, 119, 140, 125, 134, 127, 100, 101, 125, 110,
#        124, 116, 137, 125, 113,  91, 123, 115,  78, 136, 144, 160, 143,
#        110,  97, 126, 136, 146, 118, 122, 138, 112,  98, 123, 132, 122,
#        129, 136, 137, 128, 104, 143, 111, 137, 153, 143, 139, 140, 123,
#        121, 128, 136, 134, 132, 143, 113, 129, 103, 109, 124, 134, 147,
#        129, 176, 109, 141, 129, 174, 128, 131, 126, 140, 146, 119,  72,
#        139, 124, 129, 153, 114, 140, 160,  93, 115, 113, 123, 107, 109,
#        170,  85, 119, 129, 151,  93, 137, 133, 163, 110, 129, 110, 105,
#        123, 140, 127, 102, 139, 125, 130, 115, 133, 139, 116, 102, 139,
#        132, 129, 122, 130, 129,  91, 129, 134, 116, 133, 116, 129, 132,
#        121, 108, 100, 120, 122, 121,  98, 120, 139, 138, 139, 146, 137,
#        131, 124, 124, 134, 116, 110, 111, 112, 147,  78, 103, 108, 127,
#        109, 134, 103, 124, 142, 111, 105, 125, 113, 111, 155, 124, 149,
#        125, 113, 133, 121, 125, 133, 148, 142, 107, 110, 137, 143, 123,
#        123, 124, 144, 129, 147, 121, 127, 104, 119, 107, 107, 116, 124,
#        118,  97, 101, 123, 129, 135, 124, 102,  97, 127, 117, 121, 131,
#        123, 114, 120, 135,  98, 132,  89, 123,  91, 109, 125, 129, 162,
#        108, 111, 119, 129, 155, 129, 125, 126, 101, 116, 158, 113, 127,
#        130, 132, 120, 118,  98, 125, 119, 134, 164, 141, 130, 105, 114,
#        152, 128, 113, 130, 143, 129, 135,  98, 100, 113, 136, 129, 111,
#        108, 114,  98, 106, 112,  90,  75, 134, 104,  84, 148, 163, 134,
#        122, 121, 102,  84, 125, 111, 136, 127, 117, 131, 125,  91, 163,
#        103, 113, 124, 110, 144, 144, 113, 134, 113, 124, 138, 103, 114,
#        123, 119, 123, 133, 115, 137, 119, 123,  78, 143, 110, 110,  62,
#        122, 110, 109, 120, 150,  91, 164, 127, 140, 104, 160, 136, 123,
#        114, 102, 120, 124, 169, 129, 109, 124, 110, 127,  85, 121, 120,
#        112, 128, 113, 112, 139, 119, 125,  91, 148, 125, 110, 119, 148,
#        133, 120, 121, 104, 123, 129, 129, 125, 112, 112,  94, 126,  89,
#        137, 128, 109, 117])

# %%
def resample(orig_sample):
      return np.random.choice(orig_sample, size = len(orig_sample))

# %%
def bootstrap(orig_sample, reps):
    means = np.array([])
    for i in range(reps):
        new_sample = resample(orig_sample)
        new_mean = np.mean(new_sample)
        means = np. append(means, new_mean)
    return means

# %%
fertilized_means = bootstrap(fertilized, 10000)

not_fertilized_means = bootstrap(not_fertilized, 10000)

estimates = fertilized_means - not_fertilized_means

# %%
estimates
# Out:
# array([-10.24509652, -10.56300867,  -9.1247589 , ...,  -9.76627207,
#         -7.12217195,  -9.21291345])

# %%
sns.histplot(estimates)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
(np.percentile(estimates, 2.5), np.percentile(estimates, 97.5))
# Out:
# (-11.39491841491841, -7.127977665036484)
