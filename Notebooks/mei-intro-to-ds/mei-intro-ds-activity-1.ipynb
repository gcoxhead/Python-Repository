# %% [markdown]
# # MEI Introduction to Data Science
# # Activity 1 - Introduction to Python for data and using Kaggle notebooks
# # Table of Contents
#
# * [Accessing the activities for this course](#intro-activities)
#  - [Using this notebook](#notebook)
#  - [Making your own copy](#copy)
#  - [Running the code](#code)
# * [Introduction](#intro)
#  - [Problem](#problem)
#  - [Importing libraries and data](#import)
#  - [Adapting the code](#adapt)
#  - [Displaying the feature names, data types and size of the data set](#info)
#  - [Checkpoint 1](#Checkpoint-1)
# * [Exploring the data 1](#Exploring-the-data-1)
#  - [Finding the statistics for numerical data](#Finding-the-statistics-for-numerical-data)
#  - [Checkpoint 2](#Checkpoint-1)
# * [Exploring the data 2: comparing stations](#Exploring-the-data-2:-comparing-stations)
#    - [Grouping the data](#Grouping-the-data)
#    - [Exploring features grouped by station](#Exploring-features-grouped-by-station)
# * [Communicating the results](#Communicating-the-results)
#  - [Checkpoint 3](#Checkpoint-2)
# * [Extension: Pre-processing the data](#Extension:-Pre-processing-the-data)
#  - [Cleaning the Daily Total Rainfall values](#Cleaning-the-Daily-Total-Rainfall-values)
#  - [Comparing rainfall for the different weather stations](#Comparing-rainfall-for-the-different-weather-stations)
#  - [Substituting a different value for *trace*](#Substituting-a-different-value-for-trace)
#
# <a id='intro-activities'></a>
#
# # Accessing the activities for this course
#
# The activities in this course use Python program code to make it quick and easy for you to analyse a data set.
#
# This activity contains additional guidance about how to use notebooks in Kaggle. When using these notebooks you should be able to:
#
# * Run ready-made Python code in the notebook
# * Make changes to the code and see the effects
#
# <a id='notebook'></a>
# ## Using this notebook
# This page is a kind of online document called a notebook. It includes some Python code. The code has been written for you. The code will analyse the contents of the data set and show you the results.
#
# As you work through this notebook you will:
# * **run code** and look at  the results
# * **make changes** to the code and see how that changes the results
#
# <a id='copy'></a>
# ## Making your own copy
# Before you go any further, make your own personal copy of this notebook. You will need your own Kaggle account so that any changes you make to your copy are saved. Look for the button in the top right corner of this window. It says 'copy and edit'. Click this button. It might take a few seconds to create the copy. Open your copy and continue reading down this page.
#
# <a id='code'></a>
# ## Running the code
#
# The Python code appears in code boxes. Some lines start with the hashtag symbol #. These lines are comments. The comments explain what the code does.
#
# > Click anywhere in the box of code.
# > You will see an arrow to the left of the box. Click on the arrow to run the code.

# %%
# add 1 and 1
1 + 1
# Out:
# 2

# %% [markdown]
# <a id='intro'></a>
# # Introduction
# This activity uses the *Pandas* library in Python to explore problem related to a data set. Pandas is a library of tools for data analysis. You will also meet the *Seaborn* library for plotting charts.
#
# The activity uses the data from the Edexcel large data set which contains weather data for 1987 and 2015 from eight weather stations, of which five are UK weather stations. For more information about the data see the short video at: https://mei.org.uk/introduction-to-data-science/large-data-sets/
#
# <a id='problem'></a>
# ## Problem
# ***What were the main differences in weather at the locations in the dataset?***
#
# <a id='import'></a>
# ## Importing libraries and data
# The two main libraries that you will use are *pandas* (for data analysis) and *seaborn* (for plotting charts).
#
# > Run the code box below to import the libraries.

# %%
# import pandas for data analysis
import pandas as pd 

# import seaborn for visualisations
import seaborn as sns

# %% [markdown]
# The data has been attached to this notebook as a *csv* file.
#
# > Run the code in the box below to import the csv file as a data set. The output of the code will appear below it.

# %%
# import the csv file to a data set called weather_data
weather_data = pd.read_csv('../input/weather-data-edexcel-large-data-set/all-stations-uk.csv')

# display the data to verify it has imported
weather_data
# Out:
#             Date  Daily Mean Temperature Daily Total Rainfall  \
# 0     01/05/1987                    10.7                  3.1
# 1     02/05/1987                     8.9                  0.1
# 2     03/05/1987                     8.1                    0
# 3     04/05/1987                     8.2                    0
# 4     05/05/1987                     9.8                    0
# ...          ...                     ...                  ...
# 1835  27/10/2015                     8.1                    1
# 1836  28/10/2015                    11.7                    9
# 1837  29/10/2015                     9.5                  1.8
# 1838  30/10/2015                     9.9                  2.6
# 1839  31/10/2015                    11.0                  1.6
#
#       Daily Total Sunshine  Daily Mean Windspeed  \
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# ...

# %% [markdown]
# <a id='adapt'></a>
# ## Adapting the code
# The next box contains a single line of code. It outputs 6 records from the data set called 'weather_data'.
#
# > Change the code so it outputs 16 records
# >
# > What happens if you try to output 100 records? Or 1000 records?
# >
# > Try changing `head(6)` to `tail(6)` in the code. What do you think the output will be?
#
# If you make a mistake you can press Ctrl-Z to undo your changes.

# %%
weather_data.tail(6)
# Out:
#             Date  Daily Mean Temperature Daily Total Rainfall  \
# 1834  26/10/2015                     9.0                    0
# 1835  27/10/2015                     8.1                    1
# 1836  28/10/2015                    11.7                    9
# 1837  29/10/2015                     9.5                  1.8
# 1838  30/10/2015                     9.9                  2.6
# 1839  31/10/2015                    11.0                  1.6
#
#       Daily Total Sunshine  Daily Mean Windspeed  \
# 1834                   2.2                   6.0
# 1835                   0.0                  10.0
# 1836                   0.0                  11.0
# 1837                   1.4                   7.0
# 1838                   0.2                   3.0
# 1839                   2.1                   8.0
#
#      Daily Mean Windspeed (Beaufort)  Daily Maximum Gust  \
# 1834                           Light                19.0
# 1835                           Light                20.0
# ...

# %% [markdown]
# <a id='info'></a>
# ## Displaying the feature names, data types and size of a data set
# In the previous task you looked at a table of data. It contains data for every day of either 1987 or 2015 from May to October. It is composed of columns and rows.
#
# * Each column of the data table represents one **feature**. Each feature holds a different data value. Note that the term *field* is often used instead of *feature*.
# * Each row of the table represents one **record**. A record holds all the data values for a single date at a single weather station.
#
# The next block of code will output information about the data set.
#
# > Run the code now and check the result

# %%
# explore the data types
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1840 entries, 0 to 1839
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             1840 non-null   object
#  1   Daily Mean Temperature           1840 non-null   float64
#  2   Daily Total Rainfall             1840 non-null   object
#  3   Daily Total Sunshine             1759 non-null   float64
#  4   Daily Mean Windspeed             1757 non-null   float64
#  5   Daily Mean Windspeed (Beaufort)  1757 non-null   object
#  6   Daily Maximum Gust               1684 non-null   float64
#  7   Daily Maximum Relative Humidity  1840 non-null   int64
#  8   Daily Mean Total Cloud           1840 non-null   int64
#  9   Daily Mean Visibility            1840 non-null   int64
#  10  Daily Mean Pressure              1840 non-null   int64
#  11  Daily Mean Wind Direction        1840 non-null   int64
# ...

# %% [markdown]
# The code outputs a list of the features in this table. It also shows the data type of each feature. The main data types you will encounter are:
# * `int64`: integers (64 *bits* are used to store the number)
# * `float64`: a *floating point* number: i.e. includes a decimal point (64 *bits* are used to store the number)
# * `object`: this includes text features
#
# It is important to know how the features are stored as this has an impact on the type of analysis you can do, for example you will not be able to calculate a mean of a set of text values.
#
# ## Checkpoint 1
# > * How many records are there in the data set?
# > * How many features are there in the data set?
# > * Which numerical features have been imported as floating point numbers and which have been imported as integers?

# %% [markdown]
# # Exploring the data 1
# ## Finding the statistics for numerical data
# In this part of the activity you will output summary values from the table. Summary values 'summarise' the values for one feature of the table, using data from all the records in the table. For example the mean or standard deviation.
#
# The next block of code will output a list of the summary values available for the feature 'Daily Mean Temperature'.
# > Run the code and see what summary values are available for Daily Mean Temperature

# %%
# calculate the grouped summary statistics
weather_data['Daily Mean Temperature'].describe()
# Out:
# count    1840.000000
# mean       13.398043
# std         3.336363
# min         3.800000
# 25%        11.100000
# 50%        13.500000
# 75%        15.700000
# max        28.700000
# Name: Daily Mean Temperature, dtype: float64

# %% [markdown]
# This code outputs summary values for 'Daily Mean Temperature'. You should have already output a list of other feature names using the `info()` command above.
#
# > * Edit the code in the box below. to change 'Daily Mean Temperature' to the name of any other feature. See what summary values are available. Note that you must use the precise name of the feature and that it is *case-sensitive*. You can copy (ctrl-C) and paste (ctrl-v) from the list produced with `info()`.
# > * Explore the type of summary data that is available for each feature in the subset. You can add additional code boxes by pressing the *+Code* button.

# %%
# calculate the summary statistics
weather_data['Mean Cardinal Direction'].describe()
# Out:
# count     1840
# unique      16
# top          W
# freq       259
# Name: Mean Cardinal Direction, dtype: object

# %% [markdown]
# You might find it useful to see a boxplot for the data. The code in the boxes below will give a boxplot for the Daily Mean Temperature. Plotting diagrams will be explored in more detail in lesson 3.
#
# > * Run the code below to create a boxplot.
# > * Try changing the code to display the boxplots for other columns. You can use the output of `info()` to decide which columns a boxplot will be appropriate for.

# %%
# display a boxplot for a feature using catplot from Seaborn
sns.catplot(data=weather_data, kind='box', x='Daily Mean Temperature');

# %% [markdown]
# ## Checkpoint 2
# > * The command `weather_data['Daily Mean Temperature'].describe()` gave you some summary values. Go through all the summary values and say what you think each one tells you about the feature 'Daily Mean Temperature'.
# > * What summary statistics do you get if you explore a feature that is stored as an `object`?
# > * Which features in the data set is it **not** appropriate to create a boxplot for?

# %% [markdown]
# # Exploring the data 2: comparing stations
# In this part of the lesson you will compare summary values for the different weather stations.
#
# Before you begin - think about what these summary values might show. Do you expect the two data sets to be similar, or very different?
#
# ## Grouping the data
# Pandas and Seaborn both contain functions that allow you to group the data before calculating statistics or creating charts.
#
# > Run the code below to group the data by weather station and calculate the summary statistics for Daily Mean Temperature.

# %%
# calculate the grouped summary statistics
weather_data.groupby('Station')['Daily Total Sunshine'].describe()
# Out:
#           count      mean       std  min   25%  50%  75%   max
# Station
# Camborne  355.0  5.307606  4.227142  0.0  1.10  5.2  8.6  15.4
# Heathrow  351.0  5.105128  3.929300  0.0  1.50  5.0  8.2  15.1
# Hurn      351.0  5.496296  4.135845  0.0  1.65  5.5  8.6  15.0
# Leeming   351.0  4.576638  3.741393  0.0  1.25  4.1  7.1  15.9
# Leuchars  351.0  4.852137  3.844631  0.0  1.15  4.6  8.0  15.9

# %% [markdown]
# > Run the code below to create boxplots for each station for Daily Mean Temperature

# %%
# display a boxplot for a feature using catplot from Seaborn - NB the y variable groups by the categorical feature
sns.catplot(data=weather_data, kind='box', x='Daily Mean Temperature', y='Station', aspect=2);

# %% [markdown]
# ## Exploring features grouped by station
#
# > * Change the code in the boxes below so that it calculates the summary statistics and creates the box plots for some of the other numerical features.
# > * You can add additional code boxes using the *+Code* button.

# %%
# calculate the grouped summary statistics
weather_data.groupby('Station')['Daily Total Sunshine'].describe()
# Out:
#           count      mean       std  min   25%  50%  75%   max
# Station
# Camborne  355.0  5.307606  4.227142  0.0  1.10  5.2  8.6  15.4
# Heathrow  351.0  5.105128  3.929300  0.0  1.50  5.0  8.2  15.1
# Hurn      351.0  5.496296  4.135845  0.0  1.65  5.5  8.6  15.0
# Leeming   351.0  4.576638  3.741393  0.0  1.25  4.1  7.1  15.9
# Leuchars  351.0  4.852137  3.844631  0.0  1.15  4.6  8.0  15.9

# %%
# display a boxplot for a feature using catplot from Seaborn
# the y variable groups by the categorical feature
sns.catplot(data=weather_data, kind='box', x='Daily Total Sunshine', y='Station', aspect=2);

# %%
# display a boxplot for a feature using catplot from Seaborn
# the y variable groups by the categorical feature
sns.catplot(data=weather_data, kind='box', x='Daily Mean Windspeed', y='Station', aspect=2);

# %% [markdown]
# # Communicating the results
# ## Checkpoint 3
# >
# > * Use the statistics and charts produced to answer the initial problem: ***What were the main differences in weather at the locations in the dataset?***
# > * How do these statistics relate to the geographical locations of the weather stations? The image below shows the locations on a map.
#
# ![image.png](attachment:1bdea3cb-3e03-4e03-a346-ed127d155402.png)

# %% [markdown]
# # Extension: Pre-processing the data
# ## Cleaning the Daily Total Rainfall values
# Sometimes a data set has missing data values. In other cases the values might be obviously incorrect. For example in a list of temperatures you might see a single value higher than 1000. This is obviously wrong and will affect your summary values for that data set.
#
# Finding and fixing these problems is called *pre-processing* (or *cleaning*) the data. In this part of the activity you will find and fix some problems with the data set.
#
# > Run the code below to output the summary values for `Daily Total Rainfall`

# %%
# calculate the grouped summary statistics
weather_data['Daily Total Rainfall'].describe()
# Out:
# count     1840
# unique     174
# top          0
# freq       513
# Name: Daily Total Rainfall, dtype: object

# %% [markdown]
# * How are the results different from the results for 'Daily Mean Temperature'?
# * Look back at the output for `info()` at the top of this notebook. How is the rainfall data different?
#
# Many of the values you might expect to see (such as 'mean') are not calculated for Daily Total Rainfall. That is because the feature has been imported as an `object` or text feature. When importing if any of the values are text (other than "N/A") then the whole feature is imported as text. The computer can't create summary statistics from a mixture of data types. So you need to process the data before you can see summary values.
#
# The code in box below cleans the data. The value of "tr" represents a trace amount of rain less than 0.05mm therefore we are replacing it with a value in the middle of the range 0-0.05 and converting it to a number.
#
# The first command creates a copy of the feature as a new feature called 'Rainfall'.
#
# The second command replaces “tr” with 0.025 and changes every value from "object" to “float” data type so numerical statistics can be calculated.
#
# > Run the code to clean the data.

# %%
# create a new column called Rainfall which is a copy of the Daily Total Rainfall column
weather_data['Rainfall'] = weather_data['Daily Total Rainfall']

# replace any instances of 'tr' with 0.025 and change the type to float
weather_data['Rainfall'] = weather_data['Rainfall'].replace({'tr': 0.025}).astype('float')

# desplay the data to check
weather_data
# Out:
#             Date  Daily Mean Temperature Daily Total Rainfall  \
# 0     01/05/1987                    10.7                  3.1
# 1     02/05/1987                     8.9                  0.1
# 2     03/05/1987                     8.1                    0
# 3     04/05/1987                     8.2                    0
# 4     05/05/1987                     9.8                    0
# ...          ...                     ...                  ...
# 1835  27/10/2015                     8.1                    1
# 1836  28/10/2015                    11.7                    9
# 1837  29/10/2015                     9.5                  1.8
# 1838  30/10/2015                     9.9                  2.6
# 1839  31/10/2015                    11.0                  1.6
#
#       Daily Total Sunshine  Daily Mean Windspeed  \
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# ...

# %% [markdown]
# ## Comparing rainfall for the different weather stations
#
# > In the boxes below run some code to create summary statistics and box plots for rainfall grouped by weather station.

# %%
# calculate the grouped summary statistics
weather_data.groupby('Station')['Rainfall'].describe()
# Out:
#           count      mean       std  min    25%    50%    75%   max
# Station
# Camborne  368.0  2.704416  5.585979  0.0  0.000  0.200  2.625  36.4
# Heathrow  368.0  2.186005  5.652416  0.0  0.000  0.025  1.900  53.1
# Hurn      368.0  2.196807  4.917618  0.0  0.000  0.025  1.325  28.5
# Leeming   368.0  2.043818  4.434281  0.0  0.000  0.200  1.600  31.7
# Leuchars  368.0  2.134918  4.081832  0.0  0.025  0.200  2.400  31.8

# %%
# display a boxplot for a feature using catplot from Seaborn
# the y variable groups by the categorical feature
sns.catplot(data=weather_data, kind='box', x='Rainfall', y='Station', aspect=2);

# %% [markdown]
# ## Substituting a different value for *trace*
#
# The next box shows the pre-processing code again. If you have time, explore the effect of making changes to this code:
#
# > Instead of replacing 'tr' with 0.025, replace it with 0. What difference does it make to the results?
# > Try deleting the part that changes all the values to float data type. What difference does it make to the results?

# %%
# create a new column called Rainfall which is a copy of the Daily Total Rainfall column
weather_data['Rainfall'] = weather_data['Daily Total Rainfall']

# replace any instances of 'tr' with 0.025 and change the type to float
weather_data['Rainfall'] = weather_data['Rainfall'].replace({'tr': 0})

weather_data
# Out:
#             Date  Daily Mean Temperature Daily Total Rainfall  \
# 0     01/05/1987                    10.7                  3.1
# 1     02/05/1987                     8.9                  0.1
# 2     03/05/1987                     8.1                    0
# 3     04/05/1987                     8.2                    0
# 4     05/05/1987                     9.8                    0
# ...          ...                     ...                  ...
# 1835  27/10/2015                     8.1                    1
# 1836  28/10/2015                    11.7                    9
# 1837  29/10/2015                     9.5                  1.8
# 1838  30/10/2015                     9.9                  2.6
# 1839  31/10/2015                    11.0                  1.6
#
#       Daily Total Sunshine  Daily Mean Windspeed  \
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# ...

# %%
# calculate the grouped summary statistics

# %%
# display a boxplot for a feature using catplot from Seaborn
# the y variable groups by the categical feature
